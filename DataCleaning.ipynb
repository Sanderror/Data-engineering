# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/Phishing_Legitimate_full.csv")
data
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         1        3               1          5         72        0
# 1         2        3               1          3        144        0
# 2         3        3               1          2         58        0
# 3         4        3               1          6         79        1
# 4         5        3               0          4         46        0
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1          1         50        0
# 9996   9997        2               1          4         59        1
# 9997   9998        2               1          4         57        0
# 9998   9999        3               1          1         49        0
# 9999  10000        3               1          2         52        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0            0              0  ...
# ...

# %%
data.describe()
# Out:
#                 id       NumDots  SubdomainLevel     PathLevel     UrlLength  \
# count  10000.00000  10000.000000    10000.000000  10000.000000  10000.000000
# mean    5000.50000      2.445100        0.586800      3.300300     70.264100
# std     2886.89568      1.346836        0.751214      1.863241     33.369877
# min        1.00000      1.000000        0.000000      0.000000     12.000000
# 25%     2500.75000      2.000000        0.000000      2.000000     48.000000
# 50%     5000.50000      2.000000        1.000000      3.000000     62.000000
# 75%     7500.25000      3.000000        1.000000      4.000000     84.000000
# max    10000.00000     21.000000       14.000000     18.000000    253.000000
#
#             NumDash  NumDashInHostname      AtSymbol   TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  10000.000000
# mean       1.818000           0.138900      0.000300      0.013100
# std        3.106258           0.545744      0.017319      0.113709
# ...

# %%
# Create correlation heatmap
# Create correlation matrix
corr_matrix = data.corr()

# Create figure
plt.figure(figsize=(30, 24))

# Create heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')

# Show plot
plt.show()

# %%
# Select relevant columns for ML application
# Selection is based on the interpretability of the variables, as they should be easily identifiable by an individual
selected_columns = ['CLASS_LABEL', 'NumDots', 'UrlLength', 'NumDash', 'NumDashInHostname', 'AtSymbol', 'TildeSymbol', 'NumUnderscore', 'NumPercent', 'NumAmpersand', 'NumHash', 'NumNumericChars', 'NoHttps']

# Create new dataframe with only the relevant variables
data_selected  = data.loc[:, selected_columns]
data_selected
# Out:
#       CLASS_LABEL  NumDots  UrlLength  NumDash  NumDashInHostname  AtSymbol  \
# 0               1        3         72        0                  0         0
# 1               1        3        144        0                  0         0
# 2               1        3         58        0                  0         0
# 3               1        3         79        1                  0         0
# 4               1        3         46        0                  0         0
# ...           ...      ...        ...      ...                ...       ...
# 9995            0        3         50        0                  0         0
# 9996            0        2         59        1                  0         0
# 9997            0        2         57        0                  0         0
# 9998            0        3         49        0                  0         0
# 9999            0        3         52        3                  0         0
#
# ...

# %%
data_selected.describe()
# Out:
#         CLASS_LABEL       NumDots     UrlLength       NumDash  \
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.500000      2.445100     70.264100      1.818000
# std        0.500025      1.346836     33.369877      3.106258
# min        0.000000      1.000000     12.000000      0.000000
# 25%        0.000000      2.000000     48.000000      0.000000
# 50%        0.500000      2.000000     62.000000      0.000000
# 75%        1.000000      3.000000     84.000000      2.000000
# max        1.000000     21.000000    253.000000     55.000000
#
#        NumDashInHostname      AtSymbol   TildeSymbol  NumUnderscore  \
# count       10000.000000  10000.000000  10000.000000    10000.00000
# mean            0.138900      0.000300      0.013100        0.32320
# std             0.545744      0.017319      0.113709        1.11466
# min             0.000000      0.000000      0.000000        0.00000
# ...

# %%
# Create correlation heatmap
# Create correlation matrix
corr_matrix = data_selected.corr()

# Create figure
plt.figure(figsize=(30, 24))

# Create heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')

# Show plot
plt.show()

# %%
# Save new df to a scv
#data_selected.to_csv('phishing.csv', index=False)
